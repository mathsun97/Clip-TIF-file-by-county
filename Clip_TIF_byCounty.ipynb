# %%
import os

import pandas as pd
import geopandas as gpd
import numpy as np
import rasterio
import rasterstats
from rasterio.enums import Resampling
import rasterio.mask
from rasterio.plot import show
from rasterio.plot import show_hist
from rasterio.merge import merge
from shapely.geometry import Point
from random import randint, uniform
import matplotlib.pyplot as plt
import seaborn as sns
import fiona

from affine import Affine
from shapely.geometry import shape
from geopandas import GeoSeries, GeoDataFrame
from rasterio.io import MemoryFile

# %% [markdown]
# ## Clipping TIF using county shape file - Sample Code

# %%
# Read Shape file
with fiona.open('../../Working/Data/co_boundary_all_co/20001.shp', 'r') as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]

# read imagery file
with rasterio.open('../../Working/Data/nlcd_2016/nlcd_2016.tif') as src:
    out_image, out_transform = rasterio.mask.mask(src, shapes, crop=True)
    out_meta = src.meta

# Save clipped imagery
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

with rasterio.open("nl_2001_2016.tif", "w", **out_meta) as dest:
    dest.write(out_image)

# %% [markdown]
# ## Clip US imagery file to KS and NE county tif file

# %%
# County polygon lists
cnty_dir = '../../Working/Data/co_boundary_all_co/'
cnty_file_list = [file for file in os.listdir(cnty_dir) if file.endswith(".shp")]
print(len(cnty_file_list))
cnty_file_list
# Out:
# 198
# ['20001.shp',
#  '20003.shp',
#  '20005.shp',
#  '20007.shp',
#  '20009.shp',
#  '20011.shp',
#  '20013.shp',
#  '20015.shp',
#  '20017.shp',
#  '20019.shp',
#  '20021.shp',
#  '20023.shp',
#  '20025.shp',
#  '20027.shp',
#  '20029.shp',
#  '20031.shp',
#  '20033.shp',
#  '20035.shp',
#  '20037.shp',
#  '20039.shp',
#  '20041.shp',
#  '20043.shp',
#  '20045.shp',
#  '20047.shp',
#  '20049.shp',
#  '20051.shp',
#  '20053.shp',
#  '20055.shp',
#  '20057.shp',
#  '20059.shp',
#  '20061.shp',
#  '20063.shp',
#  '20065.shp',
#  '20067.shp',
#  '20069.shp',
#  '20071.shp',
#  '20073.shp',
#  '20075.shp',
#  '20077.shp',
#  '20079.shp',
#  '20081.shp',
#  '20083.shp',
#  '20085.shp',
#  '20087.shp',
#  '20089.shp',
#  '20091.shp',
#  '20093.shp',
#  '20095.shp',
#  '20097.shp',
#  '20099.shp',
#  '20101.shp',
#  '20103.shp',
#  '20105.shp',
#  '20107.shp',
#  '20109.shp',
#  '20111.shp',
#  '20113.shp',
#  '20115.shp',
#  '20117.shp',
#  '20119.shp',
#  '20121.shp',
#  '20123.shp',
#  '20125.shp',
#  '20127.shp',
#  '20129.shp',
#  '20131.shp',
#  '20133.shp',
#  '20135.shp',
#  '20137.shp',
#  '20139.shp',
#  '20141.shp',
#  '20143.shp',
#  '20145.shp',
#  '20147.shp',
#  '20149.shp',
#  '20151.shp',
#  '20153.shp',
#  '20155.shp',
#  '20157.shp',
#  '20159.shp',
#  '20161.shp',
#  '20163.shp',
#  '20165.shp',
#  '20167.shp',
#  '20169.shp',
#  '20171.shp',
#  '20173.shp',
#  '20175.shp',
#  '20177.shp',
#  '20179.shp',
#  '20181.shp',
#  '20183.shp',
#  '20185.shp',
#  '20187.shp',
#  '20189.shp',
#  '20191.shp',
#  '20193.shp',
#  '20195.shp',
#  '20197.shp',
#  '20199.shp',
#  '20201.shp',
#  '20203.shp',
#  '20205.shp',
#  '20207.shp',
#  '20209.shp',
#  '31001.shp',
#  '31003.shp',
#  '31005.shp',
#  '31007.shp',
#  '31009.shp',
#  '31011.shp',
#  '31013.shp',
#  '31015.shp',
#  '31017.shp',
#  '31019.shp',
#  '31021.shp',
#  '31023.shp',
#  '31025.shp',
#  '31027.shp',
#  '31029.shp',
#  '31031.shp',
#  '31033.shp',
#  '31035.shp',
#  '31037.shp',
#  '31039.shp',
#  '31041.shp',
#  '31043.shp',
#  '31045.shp',
#  '31047.shp',
#  '31049.shp',
#  '31051.shp',
#  '31053.shp',
#  '31055.shp',
#  '31057.shp',
#  '31059.shp',
#  '31061.shp',
#  '31063.shp',
#  '31065.shp',
#  '31067.shp',
#  '31069.shp',
#  '31071.shp',
#  '31073.shp',
#  '31075.shp',
#  '31077.shp',
#  '31079.shp',
#  '31081.shp',
#  '31083.shp',
#  '31085.shp',
#  '31087.shp',
#  '31089.shp',
#  '31091.shp',
#  '31093.shp',
#  '31095.shp',
#  '31097.shp',
#  '31099.shp',
#  '31101.shp',
#  '31103.shp',
#  '31105.shp',
#  '31107.shp',
#  '31109.shp',
#  '31111.shp',
#  '31113.shp',
#  '31115.shp',
#  '31117.shp',
#  '31119.shp',
#  '31121.shp',
#  '31123.shp',
#  '31125.shp',
#  '31127.shp',
#  '31129.shp',
#  '31131.shp',
#  '31133.shp',
#  '31135.shp',
#  '31137.shp',
#  '31139.shp',
#  '31141.shp',
#  '31143.shp',
#  '31145.shp',
#  '31147.shp',
#  '31149.shp',
#  '31151.shp',
#  '31153.shp',
#  '31155.shp',
#  '31157.shp',
#  '31159.shp',
#  '31161.shp',
#  '31163.shp',
#  '31165.shp',
#  '31167.shp',
#  '31169.shp',
#  '31171.shp',
#  '31173.shp',
#  '31175.shp',
#  '31177.shp',
#  '31179.shp',
#  '31181.shp',
#  '31183.shp',
#  '31185.shp']

# %%
# Clip by county
src = rasterio.open('../../Working/Data/nlcd_2016/nlcd_2016.tif')

for file in cnty_file_list:
    print(cnty_dir,file)
    with fiona.open(cnty_dir + file, 'r') as shapefile:
        shapes = [feature["geometry"] for feature in shapefile]  # geometry data from shape file by county
    
    out_image, out_transform = rasterio.mask.mask(src, shapes, crop=True)
    out_meta = src.meta
    
    out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

    with rasterio.open("../2016/nlcd/nl_"+file[0:5]+"_2016.tif", "w", **out_meta) as dest:
        dest.write(out_image)
# Out:
# ../../Working/Data/co_boundary_all_co/ 20003.shp
# ../../Working/Data/co_boundary_all_co/ 20005.shp
# ../../Working/Data/co_boundary_all_co/ 20007.shp
# ../../Working/Data/co_boundary_all_co/ 20009.shp
# ../../Working/Data/co_boundary_all_co/ 20011.shp
# ../../Working/Data/co_boundary_all_co/ 20013.shp
# ../../Working/Data/co_boundary_all_co/ 20015.shp
# ../../Working/Data/co_boundary_all_co/ 20017.shp
# ../../Working/Data/co_boundary_all_co/ 20019.shp
# ../../Working/Data/co_boundary_all_co/ 20021.shp
# ../../Working/Data/co_boundary_all_co/ 20023.shp
# ../../Working/Data/co_boundary_all_co/ 20025.shp
# ../../Working/Data/co_boundary_all_co/ 20027.shp
# ../../Working/Data/co_boundary_all_co/ 20029.shp
# ../../Working/Data/co_boundary_all_co/ 20031.shp
# ../../Working/Data/co_boundary_all_co/ 20033.shp
# ../../Working/Data/co_boundary_all_co/ 20035.shp
# ../../Working/Data/co_boundary_all_co/ 20037.shp
# ../../Working/Data/co_boundary_all_co/ 20039.shp
# ../../Working/Data/co_boundary_all_co/ 20041.shp
# ../../Working/Data/co_boundary_all_co/ 20043.shp
# ../../Working/Data/co_boundary_all_co/ 20045.shp
# ../../Working/Data/co_boundary_all_co/ 20047.shp
# ../../Working/Data/co_boundary_all_co/ 20049.shp
# ../../Working/Data/co_boundary_all_co/ 20051.shp
# ../../Working/Data/co_boundary_all_co/ 20053.shp
# ../../Working/Data/co_boundary_all_co/ 20055.shp
# ../../Working/Data/co_boundary_all_co/ 20057.shp
# ../../Working/Data/co_boundary_all_co/ 20059.shp
# ../../Working/Data/co_boundary_all_co/ 20061.shp
# ../../Working/Data/co_boundary_all_co/ 20063.shp
# ../../Working/Data/co_boundary_all_co/ 20065.shp
# ../../Working/Data/co_boundary_all_co/ 20067.shp
# ../../Working/Data/co_boundary_all_co/ 20069.shp
# ../../Working/Data/co_boundary_all_co/ 20071.shp
# ../../Working/Data/co_boundary_all_co/ 20073.shp
# ../../Working/Data/co_boundary_all_co/ 20075.shp
# ../../Working/Data/co_boundary_all_co/ 20077.shp
# ../../Working/Data/co_boundary_all_co/ 20079.shp
# ../../Working/Data/co_boundary_all_co/ 20081.shp
# ../../Working/Data/co_boundary_all_co/ 20083.shp
# ../../Working/Data/co_boundary_all_co/ 20085.shp
# ../../Working/Data/co_boundary_all_co/ 20087.shp
# ../../Working/Data/co_boundary_all_co/ 20089.shp
# ../../Working/Data/co_boundary_all_co/ 20091.shp
# ../../Working/Data/co_boundary_all_co/ 20093.shp
# ../../Working/Data/co_boundary_all_co/ 20095.shp
# ../../Working/Data/co_boundary_all_co/ 20097.shp
# ../../Working/Data/co_boundary_all_co/ 20099.shp
# ../../Working/Data/co_boundary_all_co/ 20101.shp
# ../../Working/Data/co_boundary_all_co/ 20103.shp
# ../../Working/Data/co_boundary_all_co/ 20105.shp
# ../../Working/Data/co_boundary_all_co/ 20107.shp
# ../../Working/Data/co_boundary_all_co/ 20109.shp
# ../../Working/Data/co_boundary_all_co/ 20111.shp
# ../../Working/Data/co_boundary_all_co/ 20113.shp
# ../../Working/Data/co_boundary_all_co/ 20115.shp
# ../../Working/Data/co_boundary_all_co/ 20117.shp
# ../../Working/Data/co_boundary_all_co/ 20119.shp
# ../../Working/Data/co_boundary_all_co/ 20121.shp
# ../../Working/Data/co_boundary_all_co/ 20123.shp
# ../../Working/Data/co_boundary_all_co/ 20125.shp
# ../../Working/Data/co_boundary_all_co/ 20127.shp
# ../../Working/Data/co_boundary_all_co/ 20129.shp
# ../../Working/Data/co_boundary_all_co/ 20131.shp
# ../../Working/Data/co_boundary_all_co/ 20133.shp
# ../../Working/Data/co_boundary_all_co/ 20135.shp
# ../../Working/Data/co_boundary_all_co/ 20137.shp
# ../../Working/Data/co_boundary_all_co/ 20139.shp
# ../../Working/Data/co_boundary_all_co/ 20141.shp
# ../../Working/Data/co_boundary_all_co/ 20143.shp
# ../../Working/Data/co_boundary_all_co/ 20145.shp
# ../../Working/Data/co_boundary_all_co/ 20147.shp
# ../../Working/Data/co_boundary_all_co/ 20149.shp
# ../../Working/Data/co_boundary_all_co/ 20151.shp
# ../../Working/Data/co_boundary_all_co/ 20153.shp
# ../../Working/Data/co_boundary_all_co/ 20155.shp
# ../../Working/Data/co_boundary_all_co/ 20157.shp
# ../../Working/Data/co_boundary_all_co/ 20159.shp
# ../../Working/Data/co_boundary_all_co/ 20161.shp
# ../../Working/Data/co_boundary_all_co/ 20163.shp
# ../../Working/Data/co_boundary_all_co/ 20165.shp
# ../../Working/Data/co_boundary_all_co/ 20167.shp
# ../../Working/Data/co_boundary_all_co/ 20169.shp
# ../../Working/Data/co_boundary_all_co/ 20171.shp
# ../../Working/Data/co_boundary_all_co/ 20173.shp
# ../../Working/Data/co_boundary_all_co/ 20175.shp
# ../../Working/Data/co_boundary_all_co/ 20177.shp
# ../../Working/Data/co_boundary_all_co/ 20179.shp
# ../../Working/Data/co_boundary_all_co/ 20181.shp
# ../../Working/Data/co_boundary_all_co/ 20183.shp
# ../../Working/Data/co_boundary_all_co/ 20185.shp
# ../../Working/Data/co_boundary_all_co/ 20187.shp
# ../../Working/Data/co_boundary_all_co/ 20189.shp
# ../../Working/Data/co_boundary_all_co/ 20191.shp
# ../../Working/Data/co_boundary_all_co/ 20193.shp
# ../../Working/Data/co_boundary_all_co/ 20195.shp
# ../../Working/Data/co_boundary_all_co/ 20197.shp
# ../../Working/Data/co_boundary_all_co/ 20199.shp
# ../../Working/Data/co_boundary_all_co/ 20201.shp
# ../../Working/Data/co_boundary_all_co/ 20203.shp
# ../../Working/Data/co_boundary_all_co/ 20205.shp
# ../../Working/Data/co_boundary_all_co/ 20207.shp
# ../../Working/Data/co_boundary_all_co/ 20209.shp
# ../../Working/Data/co_boundary_all_co/ 31001.shp
# ../../Working/Data/co_boundary_all_co/ 31003.shp
# ../../Working/Data/co_boundary_all_co/ 31005.shp
# ../../Working/Data/co_boundary_all_co/ 31007.shp
# ../../Working/Data/co_boundary_all_co/ 31009.shp
# ../../Working/Data/co_boundary_all_co/ 31011.shp
# ../../Working/Data/co_boundary_all_co/ 31013.shp
# ../../Working/Data/co_boundary_all_co/ 31015.shp
# ../../Working/Data/co_boundary_all_co/ 31017.shp
# ../../Working/Data/co_boundary_all_co/ 31019.shp
# ../../Working/Data/co_boundary_all_co/ 31021.shp
# ../../Working/Data/co_boundary_all_co/ 31023.shp
# ../../Working/Data/co_boundary_all_co/ 31025.shp
# ../../Working/Data/co_boundary_all_co/ 31027.shp
# ../../Working/Data/co_boundary_all_co/ 31029.shp
# ../../Working/Data/co_boundary_all_co/ 31031.shp
# ../../Working/Data/co_boundary_all_co/ 31033.shp
# ../../Working/Data/co_boundary_all_co/ 31035.shp
# ../../Working/Data/co_boundary_all_co/ 31037.shp
# ../../Working/Data/co_boundary_all_co/ 31039.shp
# ../../Working/Data/co_boundary_all_co/ 31041.shp
# ../../Working/Data/co_boundary_all_co/ 31043.shp
# ../../Working/Data/co_boundary_all_co/ 31045.shp
# ../../Working/Data/co_boundary_all_co/ 31047.shp
# ../../Working/Data/co_boundary_all_co/ 31049.shp
# ../../Working/Data/co_boundary_all_co/ 31051.shp
# ../../Working/Data/co_boundary_all_co/ 31053.shp
# ../../Working/Data/co_boundary_all_co/ 31055.shp
# ../../Working/Data/co_boundary_all_co/ 31057.shp
# ../../Working/Data/co_boundary_all_co/ 31059.shp
# ../../Working/Data/co_boundary_all_co/ 31061.shp
# ../../Working/Data/co_boundary_all_co/ 31063.shp
# ../../Working/Data/co_boundary_all_co/ 31065.shp
# ../../Working/Data/co_boundary_all_co/ 31067.shp
# ../../Working/Data/co_boundary_all_co/ 31069.shp
# ../../Working/Data/co_boundary_all_co/ 31071.shp
# ../../Working/Data/co_boundary_all_co/ 31073.shp
# ../../Working/Data/co_boundary_all_co/ 31075.shp
# ../../Working/Data/co_boundary_all_co/ 31077.shp
# ../../Working/Data/co_boundary_all_co/ 31079.shp
# ../../Working/Data/co_boundary_all_co/ 31081.shp
# ../../Working/Data/co_boundary_all_co/ 31083.shp
# ../../Working/Data/co_boundary_all_co/ 31085.shp
# ../../Working/Data/co_boundary_all_co/ 31087.shp
# ../../Working/Data/co_boundary_all_co/ 31089.shp
# ../../Working/Data/co_boundary_all_co/ 31091.shp
# ../../Working/Data/co_boundary_all_co/ 31093.shp
# ../../Working/Data/co_boundary_all_co/ 31095.shp
# ../../Working/Data/co_boundary_all_co/ 31097.shp
# ../../Working/Data/co_boundary_all_co/ 31099.shp
# ../../Working/Data/co_boundary_all_co/ 31101.shp
# ../../Working/Data/co_boundary_all_co/ 31103.shp
# ../../Working/Data/co_boundary_all_co/ 31105.shp
# ../../Working/Data/co_boundary_all_co/ 31107.shp
# ../../Working/Data/co_boundary_all_co/ 31109.shp
# ../../Working/Data/co_boundary_all_co/ 31111.shp
# ../../Working/Data/co_boundary_all_co/ 31113.shp
# ../../Working/Data/co_boundary_all_co/ 31115.shp
# ../../Working/Data/co_boundary_all_co/ 31117.shp
# ../../Working/Data/co_boundary_all_co/ 31119.shp
# ../../Working/Data/co_boundary_all_co/ 31121.shp
# ../../Working/Data/co_boundary_all_co/ 31123.shp
# ../../Working/Data/co_boundary_all_co/ 31125.shp
# ../../Working/Data/co_boundary_all_co/ 31127.shp
# ../../Working/Data/co_boundary_all_co/ 31129.shp
# ../../Working/Data/co_boundary_all_co/ 31131.shp
# ../../Working/Data/co_boundary_all_co/ 31133.shp
# ../../Working/Data/co_boundary_all_co/ 31135.shp
# ../../Working/Data/co_boundary_all_co/ 31137.shp
# ../../Working/Data/co_boundary_all_co/ 31139.shp
# ../../Working/Data/co_boundary_all_co/ 31141.shp
# ../../Working/Data/co_boundary_all_co/ 31143.shp
# ../../Working/Data/co_boundary_all_co/ 31145.shp
# ../../Working/Data/co_boundary_all_co/ 31147.shp
# ../../Working/Data/co_boundary_all_co/ 31149.shp
# ../../Working/Data/co_boundary_all_co/ 31151.shp
# ../../Working/Data/co_boundary_all_co/ 31153.shp
# ../../Working/Data/co_boundary_all_co/ 31155.shp
# ../../Working/Data/co_boundary_all_co/ 31157.shp
# ../../Working/Data/co_boundary_all_co/ 31159.shp
# ../../Working/Data/co_boundary_all_co/ 31161.shp
# ../../Working/Data/co_boundary_all_co/ 31163.shp
# ../../Working/Data/co_boundary_all_co/ 31165.shp
# ../../Working/Data/co_boundary_all_co/ 31167.shp
# ../../Working/Data/co_boundary_all_co/ 31169.shp
# ../../Working/Data/co_boundary_all_co/ 31171.shp
# ../../Working/Data/co_boundary_all_co/ 31173.shp
# ../../Working/Data/co_boundary_all_co/ 31175.shp
# ../../Working/Data/co_boundary_all_co/ 31177.shp
# ../../Working/Data/co_boundary_all_co/ 31179.shp
# ../../Working/Data/co_boundary_all_co/ 31181.shp
# ../../Working/Data/co_boundary_all_co/ 31183.shp
# ../../Working/Data/co_boundary_all_co/ 31185.shp

# %%
# Clip all US crop files(yearly) to county level file

# %%
cc_dir = '../../Working/Data/cc_multiple_years/'
cc_file_list = [file for file in os.listdir(cc_dir) if file.endswith(".tif")]
print(len(cc_file_list))
cc_file_list
# Out:
# 8
# ['cc_2011.tif',
#  'cc_2012.tif',
#  'cc_2013.tif',
#  'cc_2014.tif',
#  'cc_2015.tif',
#  'cc_2016.tif',
#  'cc_2017.tif',
#  'cc_2018.tif']

# %%
for cc in cc_file_list:
    src = rasterio.open(cc_dir+cc)
    for file in cnty_file_list:
        with fiona.open(cnty_dir + file, 'r') as shapefile:
            shapes = [feature["geometry"] for feature in shapefile]

        out_image, out_transform = rasterio.mask.mask(src, shapes, crop=True)
        out_meta = src.meta

        out_meta.update({"driver": "GTiff",
                     "height": out_image.shape[1],
                     "width": out_image.shape[2],
                     "transform": out_transform})

        with rasterio.open("../Crop/"+cc[3:7]+"/cc_"+file[0:5]+"_"+cc[3:7]+".tif", "w", **out_meta) as dest:
            dest.write(out_image)
